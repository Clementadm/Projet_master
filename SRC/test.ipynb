# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from API.preprocessing.get_company_news import create_news_dataset

create_news_dataset(business_name="Tesla", business_ticker="TSLA")
# Out:
# Date des articles de récupération des articles 2025-03-09
# News recover from api_news_org
# News sur 6 days 20:00:43 jours
# News recover from finhub
# News processing done and save
#      index  year  month  day         publishedAt  \
# 0        0  2025      3   22 2025-03-22 23:48:53
# 1        1  2025      3   22 2025-03-22 22:00:00
# 2        2  2025      3   22 2025-03-22 21:50:45
# 3        3  2025      3   22 2025-03-22 21:44:16
# 4        4  2025      3   22 2025-03-22 19:11:58
# ..     ...   ...    ...  ...                 ...
# 286     53  2025      3   10 2025-03-10 00:00:00
# 287      4  2025      3   10 2025-03-10 00:00:00
# 288     87  2025      3   10 2025-03-10 00:00:00
# 289     47  2025      3   10 2025-03-10 00:00:00
# 290     49  2025      3    9 2025-03-09 00:00:00
#
#                                               headline  \
# 0    Is Tesla (TSLA) Widely Held by Individuals in ...
# 1    Tesla investors at a loss as Elon Musk drags d...
# 2    X Suspends Accounts in Turkey After Government...
# 3    Elon Musk Quotes Warren Buffett Metaphor On St...
# 4    Tesla Vs. BYD: TSLA Stock Tries To Halt Slide ...
# ..                                                 ...
# 286  Elon Musk Searching for Mysterious Billionaire...
# 287  Ford’s Tesla Supercharger adapters are now on ...
# 288                         Tesla Showroom Set on Fire
# 289       Musk Melts Down as Tesla Stock Price Plunges
# 290  Tesla Is Flailing in China and the Rapid Rise ...
#
#                                                summary               source  \
# 0    We recently compiled a list of the 12 Most Wid...                Yahoo
# 1    Tesla finds itself in uncharted territory, now...                Yahoo
# 2    X has once again implemented restrictions at t...                Yahoo
# 3    Tesla Inc. (NASDAQ:TSLA) CEO Elon Musk invoked...                Yahoo
# 4    Tesla has sold off as Elon Musk spurs brand "d...                Yahoo
# ..                                                 ...                  ...
# 286                                               None  Yahoo Entertainment
# 287  Ford is making some changes to how it handles ...            The Verge
# 288  Authorities in France are investigating a susp...      Hindustan Times
# 289                                               None  Yahoo Entertainment
# 290                                               None  Yahoo Entertainment
#
#                                                    url           API
# 0    https://finnhub.io/api/news?id=a968b590896e60c...  finnhub_news
# 1    https://finnhub.io/api/news?id=109c2d5c15643e5...  finnhub_news
# 2    https://finnhub.io/api/news?id=82b7bdf5b9b152e...  finnhub_news
# 3    https://finnhub.io/api/news?id=31ba5d532d9e4c3...  finnhub_news
# 4    https://finnhub.io/api/news?id=dd8f492a6360c4c...  finnhub_news
# ..                                                 ...           ...
# 286  https://consent.yahoo.com/v2/collectConsent?se...  api_news_org
# 287  https://www.theverge.com/news/627230/ford-nacs...  api_news_org
# 288  https://www.hindustantimes.com/trending/tesla-...  api_news_org
# 289  https://consent.yahoo.com/v2/collectConsent?se...  api_news_org
# 290  https://consent.yahoo.com/v2/collectConsent?se...  api_news_org
#
# [291 rows x 10 columns]

# %%
from API.preprocessing.get_options_preprocessing import create_options_dataset
a = create_options_dataset("TSLA")
# Out:
# test
# Expirations Dates of the options ('2025-03-28', '2025-04-04', '2025-04-11', '2025-04-17', '2025-04-25', '2025-05-02', '2025-05-16', '2025-06-20', '2025-07-18', '2025-08-15', '2025-09-19', '2025-11-21', '2025-12-19', '2026-01-16', '2026-03-20', '2026-06-18', '2026-09-18', '2026-12-18', '2027-01-15', '2027-06-17')

# %%
a
# Out:
#            cluster_buy         cluster_sell  nb_option_buy  nb_option_sell  \
# 0  Price within spread  Price within spread           2161            2034
#
#    buy_mean_volume  sell_mean_volume  current_price  \
# 0       341.044455        377.881399         248.71
#
#    low_analyst_price_targets  high_analyst_price_targets  \
# 0                      120.0                       550.0
#
#    mean_analyst_price_targets  median_analyst_price_targets
# 0                    338.5826                         371.5

# %%
from API.preprocessing.get_news_country_preprocessing import get_news_country
a = get_news_country()
# Out:
# News sur 7 days 09:13:00 jours

# %%
a
# Out:
#     year  month  day                                           headline  \
# 0   2025      4    5  Meta debuts new Llama 4 models, but most power...
# 1   2025      4    5  32-year-old makes an average $13,000 a month o...
# 2   2025      4    5  This Texas city is the happiest in the U.S.—ov...
# 3   2025      4    5  From Ray-Bans to wigs, US buyers may see unexp...
# 4   2025      4    4  Trump’s claim that low tariffs caused the Grea...
# ..   ...    ...  ...                                                ...
# 95  2025      3   29  Harvard-trained expert: 3 quick habits for a h...
# 96  2025      3   29  I’m a decision coach who’s worked with over 50...
# 97  2025      3   29  'Dark Knight' star Michael Caine: Jealousy and...
# 98  2025      3   29  This old-school filmmaking technique is still ...
# 99  2025      3   29  Why it's so hard to fix the U.S. air traffic c...
#
#                                               summary     source  \
# 0   Meta has not yet released the biggest and most...       CNBC
# 1   Beau Vallis started doing music engineer in Fi...       CNBC
# 2   SmartAsset ranked cities across three categori...       CNBC
# 3   As the new levies take effect, manufacturers a...  Bloomberg
# 4   When announcing the blanket tariffs he's impos...       CNBC
# ..                                                ...        ...
# 95  Most people are wrong about what makes them ha...       CNBC
# 96  "They're making choices for the person they wi...       CNBC
# 97  Oscar-winning actor Michael Caine, 91, recentl...       CNBC
# 98  As Hollywood is grappling with the growing cap...       CNBC
# 99  The U.S. has a severe shortage of air traffic ...       CNBC
#
#                                                   url
# 0   https://www.cnbc.com/2025/04/05/meta-debuts-ne...
# 1   https://www.cnbc.com/2025/04/05/music-engineer...
# 2   https://www.cnbc.com/2025/04/05/happiest-citie...
# 3   https://www.bloomberg.com/news/articles/2025-0...
# 4   https://www.cnbc.com/2025/04/04/trumps-claim-t...
# ..                                                ...
# 95  https://www.cnbc.com/2025/03/29/happiness-expe...
# 96  https://www.cnbc.com/2025/03/29/decision-coach...
# 97  https://www.cnbc.com/2025/03/29/new-book-by-ba...
# 98  https://www.cnbc.com/2025/03/29/foley-artists-...
# 99  https://www.cnbc.com/2025/03/29/why-its-so-har...
#
# [100 rows x 7 columns]

# %%
from API.preprocessing.get_info_company_preprocessing import get_info_company_preprocessing
ab = get_info_company_preprocessing("MSFT")

# %%
ab
# Out:
#   country currency finnhubIndustry  marketCapitalization  \
# 0      US      USD      Technology          2.675044e+06
#
#                                       competitor_lst begin_analyst_period  \
# 0  MSFT, ORCL, NOW, PANW, CRWD, FTNT, ZS, GEN, RB...           2025-01-01
#
#   end_analyst_period  delta_number_days_analyst  mean_sell  mean_strongBuy  \
# 0         2025-04-01                         90        0.0             1.0
#
#    mean_strongSell  insider_sentiment
# 0              0.0                 -1
