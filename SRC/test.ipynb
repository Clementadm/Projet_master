# %%
from API.preprocessing.get_company_news import create_news_dataset

create_news_dataset(business_name="Tesla", business_ticker="TSLA")
# Out:
# Date des articles de récupération des articles 2025-01-03
# News recover from api_news_org
# News sur 7 days 09:40:02 jours
# News recover from finhub
# News processing done and save
#      index  ...           API
# 0        0  ...  finnhub_news
# 1        1  ...  finnhub_news
# 2        2  ...  finnhub_news
# 3        3  ...  finnhub_news
# 4        4  ...  finnhub_news
# ..     ...  ...           ...
# 173     68  ...  api_news_org
# 174     49  ...  api_news_org
# 175     86  ...  api_news_org
# 176     56  ...  api_news_org
# 177     90  ...  api_news_org
#
# [178 rows x 10 columns]
