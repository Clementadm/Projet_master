# %%
from datetime import datetime, timedelta
from API.get_data.api_finnhub import get_general_news_country
import pandas as pd

# %%
finnhub_country_news = get_general_news_country()
# Out:
# News sur 2 days 23:45:00 jours

# %%
finnhub_country_news = finnhub_country_news[['year', 'month', 'day', 'headline', 'source',
       'summary', 'url']]

# %%
finnhub_country_news
# Out:
#     year  month  day                                           headline  \
# 0   2025      2    2  A weak jobs report this week may refuel chatte...
# 1   2025      2    2  Here are the 11 things we're watching in the s...
# 2   2025      2    2  Questions over DeepSeek and cloud growth conti...
# 3   2025      2    2  To help pay for Trump tax cuts, new taxes on w...
# 4   2025      2    2  What's in store for remote work and RTO in 202...
# ..   ...    ...  ...                                                ...
# 95  2025      1   30  Denver awarded NWSL's 16th franchise at record...
# 96  2025      1   30  Ambanis win bid for 49% stake in Oval Invincib...
# 97  2025      1   30  I am making a call on Nvidia after watching it...
# 98  2025      1   30  Don’t count on ‘Magnificent Seven’ stocks repe...
# 99  2025      1   30  Selling your house? Here’s how long you’ll hav...
#
#          source                                            summary  \
# 0   MarketWatch  A softer-than-expected jobs report to be relea...
# 1          CNBC  Jobs data and earnings from the likes of Amazo...
# 2   MarketWatch  DeepSeek last week shook markets with its prom...
# 3          CNBC  The GOP Congress is looking at including emplo...
# 4          CNBC  Some CEOs hope renewed RTO efforts will get wo...
# ..          ...                                                ...
# 95         CNBC  The latest NWSL team sale demonstrates the hea...
# 96    Bloomberg  This strengthens the Hundred format in the UK ...
# 97         CNBC      What to do with Nvidia after a terrible week?
# 98  MarketWatch  Only buying last year’s winners may actually c...
# 99  MarketWatch  High mortgage rates have stalled the housing m...
#
#                                                   url
# 0   https://www.marketwatch.com/story/a-weak-jobs-...
# 1   https://www.cnbc.com/2025/02/02/here-are-the-1...
# 2   https://www.marketwatch.com/story/questions-ov...
# 3   https://www.cnbc.com/2025/02/02/to-help-pay-fo...
# 4   https://www.cnbc.com/2025/02/02/whats-in-store...
# ..                                                ...
# 95  https://www.cnbc.com/2025/01/30/denver-awarded...
# 96  https://www.bloomberg.com/news/articles/2025-0...
# 97  https://www.cnbc.com/2025/01/30/cramer-tough-c...
# 98  https://www.marketwatch.com/story/dont-count-o...
# 99  https://www.marketwatch.com/story/selling-your...
#
# [100 rows x 7 columns]

# %%
finnhub_country_news["day"].value_counts()
# Out:
# day
# 31    57
# 30    22
# 1     15
# 2      6
# Name: count, dtype: int64
