# %%
import os
import sys
from pathlib import Path

# %%
current_dir = os.getcwd()
sys.path.append(str(Path(current_dir).parent))

# %%
str(Path(current_dir).parent)
# Out:
# 'c:\\Users\\cleme\\Documents\\Ynov\\M2\\Projet Master\\Projet Bourse\\NEW\\Projet_master\\SRC'
