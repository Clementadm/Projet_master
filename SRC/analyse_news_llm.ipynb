# %%
from API.preprocessing.get_company_news import create_news_dataset

# %%
a = create_news_dataset(business_name="Tesla", business_ticker="TSLA")
# Out:
# Date des articles de récupération des articles 2025-06-24
# News recover from api_news_org
# News sur 5 days 20:51:55 jours
# News recover from finhub
# News processing done and save

# %%
a
# Out:
#      index  year  month  day         publishedAt  \
# 0        0  2025      7    8 2025-07-08 08:05:08
# 1        1  2025      7    8 2025-07-08 06:51:12
# 2        2  2025      7    8 2025-07-08 03:21:07
# 3        3  2025      7    8 2025-07-08 00:18:02
# 4        4  2025      7    8 2025-07-08 00:15:00
# ..     ...   ...    ...  ...                 ...
# 316     13  2025      6   24 2025-06-24 00:00:00
# 317     75  2025      6   24 2025-06-24 00:00:00
# 318     19  2025      6   24 2025-06-24 00:00:00
# 319     54  2025      6   24 2025-06-24 00:00:00
# 320     78  2025      6   24 2025-06-24 00:00:00
#
#                                               headline  \
# 0    China June Car Sales Rise Despite Pressure to ...
# 1    China car sales jump in June but EV price war ...
# 2    Tesla shares slump after Musk plots new US pol...
# 3    Azoria Delays Tesla ETF After Musk Launches Po...
# 4    Tariff whiplash, oil prices, Tesla turmoil: Ma...
# ..                                                 ...
# 316  Tesla faces robotaxi hurdles while Waymo keeps...
# 317  Tesla: Nach Robotaxi-Start prüfen die US-Behör...
# 318  Tesla no ha lanzado solo un robotaxi. Ha lanza...
# 319  Tesla Robotaxi Probed By Feds After Just One D...
# 320  BYD : voici les photos officielles du nouveau ...
#
#                                                summary               source  \
# 0    By Jiahui Huang China's auto sales grew sharpl...              Finnhub
# 1    China's car sales rose inJune for the fifth st...              Finnhub
# 2    TESLA has once again lost its status as a tril...              Finnhub
# 3    ETF listing paused amid uncertainty over Elon ...                Yahoo
# 4    US stocks (^GSPC, ^IXIC, ^DJI) slipped on Mond...                Yahoo
# ..                                                 ...                  ...
# 316  Tesla's (TSLA) robotaxi launch hit some early ...  Yahoo Entertainment
# 317  Tesla hat in den USA gestern bereits damit beg...         Caschys Blog
# 318  Elon Musk sacaba pecho el domingo. Y con razón...           Xataka.com
# 319  Tesla's self-driving cars are already under in...             Jalopnik
# 320  Déjà annoncée depuis quelques semaines, la nou...            Frandroid
#
#                                                    url           API
# 0    https://finnhub.io/api/news?id=bbfa72de3ef21c0...  finnhub_news
# 1    https://finnhub.io/api/news?id=9980caaee0e1368...  finnhub_news
# 2    https://finnhub.io/api/news?id=901b626800f9950...  finnhub_news
# 3    https://finnhub.io/api/news?id=31bd85a44b09088...  finnhub_news
# 4    https://finnhub.io/api/news?id=c29cb6edf66b78e...  finnhub_news
# ..                                                 ...           ...
# 316  https://finance.yahoo.com/video/tesla-faces-ro...  api_news_org
# 317  https://stadt-bremerhaven.de/tesla-nach-robota...  api_news_org
# 318  https://www.xataka.com/movilidad/tesla-no-ha-l...  api_news_org
# 319  https://www.jalopnik.com/1894249/tesla-robotax...  api_news_org
# 320  https://www.frandroid.com/marques/byd/2658623_...  api_news_org
#
# [321 rows x 10 columns]
