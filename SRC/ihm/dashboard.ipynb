# %%
import streamlit as st
import pandas as pd
# import altair as alt
import plotly.express as px

# %%
st.set_page_config(
    page_title="US Population Dashboard",
    page_icon="🏂",
    layout="wide",
    initial_sidebar_state="expanded")

# alt.themes.enable("dark")
# Out:
# 2025-07-12 17:51:34.062 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import json
import pandas as pd

# %%
# # Read JSON file
# with open(r"C:\Users\cleme\Documents\Ynov\M2\Projet Master\Projet Bourse\NEW\Projet_master\data\output\all_data_regroup\anf_data_2025_07_09.json", "r", encoding="utf-8") as f:
#     output_data = json.load(f)

# # Use the output_data
# pd.read_json(output_data["info_company"])

# %%
df=pd.read_csv('us-population-2010-2019.csv')

# %%
df_reshaped = pd.melt(df, id_vars=['states', 'id'], var_name='year', value_name='population')

# Convert 'year' column values to integers
df_reshaped['states'] = df_reshaped['states'].astype(str)
df_reshaped['year'] = df_reshaped['year'].astype(int)
df_reshaped['population'] = df_reshaped['population'].str.replace(',', '').astype(int)

df_reshaped
# Out:
#             states  id  year  population
# 0          Alabama   1  2010     4785437
# 1           Alaska   2  2010      713910
# 2          Arizona   4  2010     6407172
# 3         Arkansas   5  2010     2921964
# 4       California   6  2010    37319502
# ..             ...  ..   ...         ...
# 515     Washington  53  2019     7614893
# 516  West Virginia  54  2019     1792147
# 517      Wisconsin  55  2019     5822434
# 518        Wyoming  56  2019      578759
# 519    Puerto Rico  72  2019     3193694
#
# [520 rows x 4 columns]

# %%
with st.sidebar:
    st.title('🏂 US Population Dashboard')
    
    year_list = list(df_reshaped.year.unique())[::-1]
    
    selected_year = st.selectbox('Select a year', year_list, index=len(year_list)-1)
    df_selected_year = df_reshaped[df_reshaped.year == selected_year]
    df_selected_year_sorted = df_selected_year.sort_values(by="population", ascending=False)

    color_theme_list = ['blues', 'cividis', 'greens', 'inferno', 'magma', 'plasma', 'reds', 'rainbow', 'turbo', 'viridis']
    selected_color_theme = st.selectbox('Select a color theme', color_theme_list)
# Out:
# 2025-07-12 18:00:30.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.455 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.457 Session state does not function when running a script without `streamlit run`
# 2025-07-12 18:00:30.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.462 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-12 18:00:30.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
